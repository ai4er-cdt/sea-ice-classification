# %%
import geopandas as gpd
import rasterio
from rasterio.plot import show
from rasterio.plot import show_hist
import rasterstats
import matplotlib.pyplot as plt
import georasters as gr

# %%
# Sea Ice Chart Images
Chart_2017_11_06 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20171106.tiff')
Chart_2017_12_23 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20171223.tiff')
Chart_2018_01_04 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20180104.tiff')
Chart_2018_02_22 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20180222.tiff')
Chart_2018_02_23 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20180223.tiff')
Chart_2018_02_26 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20180226.tiff')
Chart_2018_12_03 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20181203.tiff')
Chart_2018_12_09 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20181209.tiff')
Chart_2018_12_10 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20181210.tiff')
Chart_2018_12_17 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20181217.tiff')
Chart_2018_12_20 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20181220.tiff')
Chart_2018_12_28 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20181228.tiff')
Chart_2019_03_13 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20190313.tiff')
Chart_2020_01_17 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20200117.tiff')
Chart_2020_03_05 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20200305.tiff')
Chart_2020_03_13 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20200313.tiff')
Chart_2020_11_04 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20201104.tiff')
Chart_2020_11_05 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20201105.tiff')
Chart_2021_12_23 = rasterio.open('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20211223.tiff')

# %% [markdown]
# # Weddell Sea 2017

# %%
# Plotting raster & shapefile
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,4))
show_hist(Chart_2017_11_06, title = 'Nov 6 2017', ax=ax1)
show_hist(Chart_2017_12_23, title = 'Dec 23 2017', ax=ax2)

ax1.get_legend().remove()
ax2.get_legend().remove()

ax1.set(ylabel=None, xlabel=None)
ax2.set(ylabel=None, xlabel=None)

plt.show()

# %%
chartNov2017 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20171106.tiff')
chartDec2017 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20171223.tiff')

arrayNov2017 = chart2017.to_pandas()
arrayDec2017 = chart2017.to_pandas()

Nov2017_CT_values = arrayNov2017.iloc[:, 2]
Dec2017_CT_values = arrayDec2017.iloc[:, 2]

Nov2017_unique_CT_values = Nov2017_CT_values.unique()
Dec2017_unique_CT_values = Dec2017_CT_values.unique()

print(Nov2017_unique_CT_values)
print(Dec2017_unique_CT_values)

# %% [markdown]
# # Weddell Sea 2018

# %%
# Plotting raster & shapefile
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize=(10,4))
show_hist(Chart_2018_01_04, title = 'Jan 4 2018', ax=ax1)
show_hist(Chart_2018_02_22, title = 'Feb 22 2018', ax=ax2)
show_hist(Chart_2018_02_23, title = 'Feb 23 2018', ax=ax3)
show_hist(Chart_2018_02_26, title = 'Feb 26 2018', ax=ax4)

ax1.get_legend().remove()
ax2.get_legend().remove()
ax3.get_legend().remove()
ax4.get_legend().remove()

ax1.set(ylabel=None, xlabel=None)
ax2.set(ylabel=None, xlabel=None)
ax3.set(ylabel=None, xlabel=None)
ax4.set(ylabel=None, xlabel=None)

plt.show()

# %%
chartJan042018 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20180104.tiff')
chartFeb222018 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20180222.tiff')
chartFeb232018 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20180223.tiff')
chartFeb262018 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20180226.tiff')

arrayJan042018 = chartJan042018.to_pandas()
arrayFeb222018 = chartFeb222018.to_pandas()
arrayFeb232018 = chartFeb232018.to_pandas()
arrayFeb262018 = chartFeb262018.to_pandas()

Jan042018_CT_values = arrayJan042018.iloc[:, 2]
Feb222018_CT_values = arrayFeb222018.iloc[:, 2]
Feb232018_CT_values = arrayFeb232018.iloc[:, 2]
Feb262018_CT_values = arrayFeb262018.iloc[:, 2]

Jan042018_unique_CT_values = Jan042018_CT_values.unique()
Feb222018_unique_CT_values = Feb222018_CT_values.unique()
Feb232018_unique_CT_values = Feb232018_CT_values.unique()
Feb262018_unique_CT_values = Feb262018_CT_values.unique()

print(Jan042018_unique_CT_values)
print(Feb222018_unique_CT_values)
print(Feb232018_unique_CT_values)
print(Feb232018_unique_CT_values)
# Out:
# [46.  0. 90. 92. 91. 13.]
# [81. 92. 13. 24. 68. 46.]
# [92. 81. 13. 24.]
# [92. 81. 13. 24.]

# %% [markdown]
# # Weddel Sea 2019

# %%
# Plotting raster & shapefile
fig, (ax1) = plt.subplots(1,1, figsize=(10,4))
show_hist(Chart_2019_03_13, title = '13 March 2019', ax=ax1)

ax1.get_legend().remove()

ax1.set(ylabel=None, xlabel=None)

plt.show()

# %%
chartMarch132019 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20190313.tiff')

arrayMarch132019 = chartMarch132019.to_pandas()

March132019_CT_values = arrayMarch132019.iloc[:, 2]

March132019_unique_CT_values = March132019_CT_values.unique()

print(March132019_unique_CT_values)
# Out:
# [ 92.   0. 247.  91.]

# %% [markdown]
# # Weddel Sea 2020

# %%
# Plotting raster & shapefile
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5, figsize=(10,4))
show_hist(Chart_2020_01_17, title = '17 Jan', ax=ax1)
show_hist(Chart_2020_03_05, title = '5 March', ax=ax2)
show_hist(Chart_2020_03_13, title = '13 March', ax=ax3)
show_hist(Chart_2020_11_04, title = '4 Nov', ax=ax4)
show_hist(Chart_2020_11_05, title = '5 Nov', ax=ax5)

ax1.get_legend().remove()
ax2.get_legend().remove()
ax3.get_legend().remove()
ax4.get_legend().remove()
ax5.get_legend().remove()

ax1.set(ylabel=None, xlabel=None)
ax2.set(ylabel=None, xlabel=None)
ax3.set(ylabel=None, xlabel=None)
ax4.set(ylabel=None, xlabel=None)
ax5.set(ylabel=None, xlabel=None)

plt.show()

# %%
chartJan172020 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20200117.tiff')
chartMarch052020 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20200305.tiff')
chartMarch132020 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20200313.tiff')
chartNov042020 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20201104.tiff')
chartNov0520120 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20201105.tiff')

arrayJan172020 = chartJan172020.to_pandas()
arrayMarch052020 = chartMarch052020.to_pandas()
arrayMarch132020 = chartMarch132020.to_pandas()
arrayNov042020 = chartNov042020.to_pandas()
arrayNov0520120 = chartNov0520120.to_pandas()

Jan172020_CT_values = arrayJan172020.iloc[:, 2]
March052020_CT_values = arrayMarch052020.iloc[:, 2]
March132020_CT_values = arrayMarch132020.iloc[:, 2]
Nov0520120_CT_values = arrayNov0520120.iloc[:, 2]
Nov042020_CT_values = arrayNov042020.iloc[:, 2]

Jan172020_unique_CT_values = Jan172020_CT_values.unique()
March052020_unique_CT_values = March052020_CT_values.unique()
March132020_unique_CT_values = March132020_CT_values.unique()
Nov0520120_unique_CT_values = Nov0520120_CT_values.unique()
Nov042020_unique_CT_values = Nov042020_CT_values.unique()

print(Jan172020_unique_CT_values)
print(March052020_unique_CT_values)
print(March132020_unique_CT_values)
print(Nov0520120_unique_CT_values)
print(Nov042020_unique_CT_values)
# Out:
# [81. 24. 13. 92. 46.  0.]
# [92. 81. 46.]
# [92. 81. 68.]
# [92.]

# %% [markdown]
# # Weddel Sea 2021

# %%
# Plotting raster & shapefile
fig, (ax1) = plt.subplots(1,1, figsize=(10,4))
show_hist(Chart_2021_12_23, title = '23 Dec 2021', ax=ax1)

ax1.get_legend().remove()

ax1.set(ylabel=None, xlabel=None)

plt.show()

# %%
chartJan042018 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20211223.tiff')

arrayDec232021 = chartDec232021.to_pandas()

Dec232021_CT_values = arrayDec232021.iloc[:, 2]

Dec232021_unique_CT_values = Dec232021_CT_values.unique()

print(Dec232021_unique_CT_values)

# %% [markdown]
# # Extra Data: Antarctic Peninsula 2018

# %%
# Plotting raster & shapefile
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5, figsize=(10,4))
show_hist(Chart_2018_12_20, title = '20 Dec', ax=ax1)
show_hist(Chart_2018_12_17, title = '17 Dec', ax=ax2)
show_hist(Chart_2018_12_10, title = '10 Dec', ax=ax3)
show_hist(Chart_2018_12_09, title = '9 Dec', ax=ax4)
show_hist(Chart_2018_12_03, title = '3 Dec', ax=ax5)

ax1.get_legend().remove()
ax2.get_legend().remove()
ax3.get_legend().remove()
ax4.get_legend().remove()
ax5.get_legend().remove()

ax1.set(ylabel=None, xlabel=None)
ax2.set(ylabel=None, xlabel=None)
ax3.set(ylabel=None, xlabel=None)
ax4.set(ylabel=None, xlabel=None)
ax5.set(ylabel=None, xlabel=None)

plt.show()

# %%
chartDec202018 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20181220.tiff')
chartDec172018 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20181217.tiff')
chartDec102018 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20181210.tiff')
chartDec92018 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20181209.tiff')
chartDec32018 = gr.from_file('/gws/nopw/j04/ai4er/guided-team-challenge/2023/FTP_data/rasterised_shapefiles/20181203.tiff')

arrayDec202018 = chartDec202018.to_pandas()
arrayDec172018 = chartDec172018.to_pandas()
arrayDec102018 = chartDec102018.to_pandas()
arrayDec92018 = chartDec92018.to_pandas()
arrayDec32018 = chartDec32018.to_pandas()

Dec202018_CT_values = arrayDec202018.iloc[:, 2]
Dec172018_CT_values = arrayDec172018.iloc[:, 2]
Dec102018_CT_values = arrayDec102018.iloc[:, 2]
Dec92018_CT_values = arrayDec92018.iloc[:, 2]
Dec32018_CT_values = arrayDec32018.iloc[:, 2]

Dec202018_unique_CT_values = Dec202018_CT_values.unique()
Dec172018_unique_CT_values = Dec172018_CT_values.unique()
Dec102018_unique_CT_values = Dec102018_CT_values.unique()
Dec92018_unique_CT_values = Dec92018_CT_values.unique()
Dec32018_unique_CT_values = Dec32018_CT_values.unique()

print(Dec202018_unique_CT_values)
print(Dec172018_unique_CT_values)
print(Dec102018_unique_CT_values)
print(Dec92018_unique_CT_values)
print(Dec32018_unique_CT_values)
